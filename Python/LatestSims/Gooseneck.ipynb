# %%
from ece470_lib import *
from IPython.display import clear_output
from time import time
inTOmm = 25.4;

# Joint Axes Orientations
a0 = [0, 0,1.0001];
a1 = [0,-1.0001,0];
a2 = [0,-1.0001,0];
a3 = [0,-1.0001,0];
a4 = [1.0001, 0,0];
a5 = [0, 0,1.0001];

# Joint Axes Positions (Ant point on axis)
q0 = [0,0,0];
q1 = [3.76*inTOmm,0.0001,8.11*inTOmm];
q2 = [11.76*inTOmm,0.0001,8.11*inTOmm];
q3 = [17.76*inTOmm,0.0001,8.11*inTOmm];
q4 = [19.48*inTOmm,0.0001,8.11*inTOmm];
q5 = [19.48*inTOmm+50,0,8.11*inTOmm];

# Convert to Screws (rotation about an axis+linear motions along screw)
s0 = toScrew(a0,q0);
s1 = toScrew(a1,q1);
s2 = toScrew(a2,q2);
s3 = toScrew(a3,q3);
s4 = toScrew(a4,q4);
s5 = toScrew(a5,q5);

# Assemble Screw Bank
S=[s0,s1,s2,s3,s4,s5]


#       [xToolInSpace, yToolInSpace, zToolInSpace]
toolRot = np.array([[ 1,0,0],# tool frame axes expressed in space frame coordiantes
                    [ 0,1,0],
                    [ 0,0,1]]);

toolPos = np.array([[19.48*inTOmm+50 , 0 , 8.11*inTOmm+400]]).transpose(); #position of tool end in space frame
M=toPose(toolRot,toolPos); # Assemble Pose Matrix of Tool in space frame coordiantes

# define goal Pose
goalRot = np.eye(3);
X=np.arange(-600,600,10);
# Y=X;
Y=np.array([0])
Z=np.arange(400,1020,10)
print (X.shape,Y.shape,Z.shape)
# Out:
# (120,) (1,) (62,)

# %%
# %who
# Out:
# Dist3D	 M	 S	 Tree	 X	 Y	 Z	 a0	 a1
# a2	 a3	 a4	 a5	 adj_T	 bracket	 checkcollision	 checkselfcollision	 clear_output
# evalJ	 evalT	 expm	 finalpos	 findIK	 fromPose	 goalRot	 inTOmm	 inv_bracket
# isValidTheta	 logm	 matrix_linspace	 multi_transform	 norm	 np	 pinv	 q0	 q1
# q2	 q3	 q4	 q5	 s0	 s1	 s2	 s3	 s4
# s5	 sequential_Ts	 skew4	 time	 toPose	 toScrew	 toTs	 toolPos	 toolRot
# validThetas

# %%
import matplotlib.pyplot as plt

ang= 0
validThetaGoose, thetaMapGoose = validThetas(X,Y,Z,S,M,goalRot,ang)
# Out:
# 0.0 min until done

# %%
# %store thetaMapGoose
# %store validThetaGoose
# %store -r validThetaGoose
# %store -r thetaMapGoose
# Out:
# Stored 'thetaMapGoose' (list)
# Stored 'validThetaGoose' (ndarray)

# %%
# goalRot = np.eye(3);
# goalPos = np.array([[450],[0],[850]]);
# goalT = toPose(goalRot,goalPos);
# thetaMat,norm = findIK(goalT, S,M,max_iter=100);
# print(thetaMat)
# out = evalT(S,[0,20/180*np.pi,130/180*np.pi,-60/180*np.pi,0],M)
# rot,pos = fromPose(out)
# print(rot)
# print(pos)

# %%
# i=np.where(X==440)[0][0]
# j=0
# k=np.where(Z==840)[0][0]
# print(X[i],Y[j],Z[k])
# print(thetaMap[i][j][k])

# %%
# shp = [len(thetaMap),len(thetaMap[0]),len(thetaMap[0][0])]
# for i in range(shp[0]):
#     for j in range(shp[1]):
#         for k in range(shp[2]):
#             print([X[i],Y[j],Z[k]])
#             for thet in thetaMap[i][j][j]:
#                 print(thet)
#             print()

# %%
# count=0
# for i in range(validTheta.shape[0]):
#     for j in range(validTheta.shape[1]):
#         for k in range(validTheta.shape[2]):
#             if(validTheta[i,j,k]==0):
#                 print((X[i],Y[j],Z[k]));
#                 count+=1
                
# print("unreachable points =", count)

# %%
# print(thetaMap[0][0][0])

# %%
# from time import gmtime
# tmstop = gmtime()

# %%
# print(tmstop)

# %%
# print(isValidTheta([[159],[120]]))

# %%
validTheta=validThetaGoose
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
plt.minorticks_on()
plt.grid(b=True, which='major', color='black', linestyle='-')
plt.grid(b=True, which='minor', color='gray', linestyle='--')
plt.xlim(-550,550)
plt.ylim(400,1020)
plt.xlabel('X (mm)')
plt.ylabel('Z (mm)')
xs=[]
zs=[]
for i in range(X.size):
    for j in range(Y.size):
        for k in range(Z.size):
            if(validTheta[i,j,k]>0):
                xs.append(X[i])
                zs.append(Z[k])
#                 print(validTheta[i,j,k])
for i in range(len(zs)):
    zs[i]=zs[i]
# print(xs)
# print(zs)
plt.scatter(xs,zs,s=50,color='gray')
plt.title("Dorna 1 Achievable XZ positions w/ 40cm Tool Gooseneck")
plt.savefig("XZ_SpatialFreedom40cmToolGooseneck.png")
xsGoose = xs
zsGoose = zs

# %%
# %store xsGoose zsGoose
# %store -r xsGoose zsGoose
# Out:
# Stored 'xsGoose' (list)
# Stored 'zsGoose' (list)

# %%
from math import sqrt
goalRot = np.array([[sqrt(2)/2,0,-sqrt(2)/2],[0,1,0],[sqrt(2)/2,0,sqrt(2)/2]]).transpose()
xs = np.array(xs)
zs = np.array(zs)

# %%
ang = -np.pi/4
validThetaMinus45Goose, thetaMapMinus45Goose = validThetas(X,Y,Z,S,M,goalRot,ang)
# validThetaMinus45Goose, thetaMapMinus45Goose = validThetas(np.array([-570]),np.array([0]),np.array([710]),S,M,goalRot,ang)
# [-300, 0, 400]
# Out:
# 473.28211048440096 min until done
# valid= 0 invalid= 1781 tested 1781 out of 7440 [-320, 0, 850]
# logm result may be inaccurate, approximate err = 2.3596727452929414e-12
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-16-ea901045e11b> in <module>
#       1 ang = -np.pi/4
# ----> 2 validThetaMinus45Goose, thetaMapMinus45Goose = validThetas(X,Y,Z,S,M,goalRot,ang)
#       3 # validThetaMinus45Goose, thetaMapMinus45Goose = validThetas(np.array([-570]),np.array([0]),np.array([710]),S,M,goalRot,ang)
#       4 # [-300, 0, 400]
#
# ~/Desktop/NuCurrent/MBDorna/Robotics/Python/LatestSims/ece470_lib.py in validThetas(X, Y, Z, S, M, goalRot, ang)
#     476                 goalPos = np.array([[X[i],Y[j],Z[k]]]).transpose();
#     477                 goalT = toPose(goalRot,goalPos);
# --> 478                 thetaMat,norm = findIK(goalT, ang, S,M,max_iter=100);
#     479                 clear_output(wait=True)
#     480                 if(len(thetaMat)>0):
#
# ~/Desktop/NuCurrent/MBDorna/Robotics/Python/LatestSims/ece470_lib.py in findIK(endT, ang, S, M, theta, max_iter, max_err, mu)
#     254             V = inv_bracket(temp2)
#     255             J = evalJ(S, theta)
# --> 256             peeinv = pinv(J.transpose().dot(J) + mu*np.identity(S.shape[1])).dot(J.transpose())
#     257             thetadot = peeinv.dot(V)
#     258
#
# <__array_function__ internals> in pinv(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in pinv(a, rcond, hermitian)
#    1959         return wrap(res)
#    1960     a = a.conjugate()
# -> 1961     u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    1962
#    1963     # discard small singular values
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1624
#    1625         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1626         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1627         u = u.astype(result_t, copy=False)
#    1628         s = s.astype(_realType(result_t), copy=False)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_svd_nonconvergence(err, flag)
#     104
#     105 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 106     raise LinAlgError("SVD did not converge")
#     107
#     108 def _raise_linalgerror_lstsq(err, flag):
#
# LinAlgError: SVD did not converge

# %% [markdown]
# valid= 0 invalid= 217 tested 217 out of 7440 [-570, 0, 710]

# %%
# %store validThetaMinus45Goose
# %store -r validThetaMinus45Goose
# print(validThetaMinus45Goose)

# %%
validTheta=validThetaMinus45Goose
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.minorticks_on()
plt.grid(b=True, which='major', color='black', linestyle='-')
plt.grid(b=True, which='minor', color='gray', linestyle='-')
plt.xlim(-10,550)
plt.ylim(400,1050)
plt.xlabel('X (mm)')
plt.ylabel('Z (mm)')
xs45=[]
zs45=[]
for i in range(X.size):
    for j in range(Y.size):
        for k in range(Z.size):
            if(validTheta[i,j,k]>0):
                xs45.append(X[i])
                zs45.append(Z[k])
for i in range(len(zs45)):
    zs45[i]=zs45[i]
plt.scatter(xs,zs,s=50,color='blue')
plt.scatter(xs45,zs45,s=30,color='red')
def split(l1,l2):
    same=[]
    foundSame = np.zeros((len(l1),len(l2)))
    for i in range(len(ll)):
        for j in range(len(l2)):
            if(l1[i]==l2[j]):
                same.append(l1[i])
                foundSame[i,j]=1
    return same

plt.title("Dorna 1 Achievable XZ positions -45deg w/ 40cm Tool Gooseneck")
plt.savefig("XZ_SpatialFreedomMinus45degWithGooseneck40cmTool.png")
